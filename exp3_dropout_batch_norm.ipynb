# %%
import matplotlib as plt
import pandas as pd
import numpy as np
import keras
from tqdm import tqdm
from keras.preprocessing import image
import matplotlib 
from matplotlib import pyplot as plt
import os
import cv2
# Out:
# 2024-06-08 20:04:15.593641: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 20:04:15.593690: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 20:04:15.593726: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-08 20:04:15.601654: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-08 20:04:16.917356: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = []
labels = []
classes = 43
cur_path = 'Train'

for i in tqdm(os.listdir(cur_path)):
    dir = cur_path + '/' + i
    for j in os.listdir(dir):
        img_path = dir+'/'+j
        img = cv2.imread(img_path,-1)
        img = cv2.resize(img, (64,64), interpolation = cv2.INTER_NEAREST)
        data.append(img)
        labels.append(i)
        
data = np.array(data)
labels = np.array(labels)
print(data.shape, labels.shape)
# Out:
# 100%|██████████| 43/43 [00:07<00:00,  5.51it/s]
# (39209, 64, 64, 3) (39209,)

# %%
plt.imshow(data[3907])

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, AveragePooling2D, Flatten, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf

x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size= 0.25, random_state=21)

print((x_train.shape, y_train.shape), (x_test.shape, y_test.shape))

# converting the labels into one hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 43)
y_test = tf.keras.utils.to_categorical(y_test, 43)
# Out:
# ((29406, 64, 64, 3), (29406,)) ((9803, 64, 64, 3), (9803,))

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu', input_shape=(64,64,3)))
model.add(AveragePooling2D(pool_size = (2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(AveragePooling2D(pool_size = (2, 2)))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(units=120, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=84, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=43, activation = 'softmax'))
# Out:
# 2024-06-08 20:04:30.074846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-08 20:04:30.166037: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 32)        2432
#
#  average_pooling2d (Average  (None, 30, 30, 32)        0
#  Pooling2D)
#
#  batch_normalization (Batch  (None, 30, 30, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        25632
#
#  average_pooling2d_1 (Avera  (None, 13, 13, 32)        0
#  gePooling2D)
#
#  batch_normalization_1 (Bat  (None, 13, 13, 32)        128
#  chNormalization)
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 120)               649080
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dropout_1 (Dropout)         (None, 84)                0
#
#  dense_2 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 691219 (2.64 MB)
# Trainable params: 691091 (2.64 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
import visualkeras
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=794x356>

# %%
epochs = 15
history = model.fit(x_train, y_train, 
                   batch_size=64,
                   epochs=epochs,
                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 2024-06-08 20:04:31.044864: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 361340928 exceeds 10% of free system memory.
#   1/460 [..............................] - ETA: 9:32 - loss: 5.3585 - accuracy: 0.0312
# 2024-06-08 20:04:32.936874: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 29491200 exceeds 10% of free system memory.
# 2024-06-08 20:04:32.999087: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 30284800 exceeds 10% of free system memory.
# 2024-06-08 20:04:32.999211: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 30284800 exceeds 10% of free system memory.
# 2024-06-08 20:04:33.050521: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 29491200 exceeds 10% of free system memory.
# 460/460 [==============================] - 53s 112ms/step - loss: 2.1587 - accuracy: 0.4282 - val_loss: 0.7046 - val_accuracy: 0.8314
# Epoch 2/15
# 460/460 [==============================] - 54s 117ms/step - loss: 0.8660 - accuracy: 0.7369 - val_loss: 0.2671 - val_accuracy: 0.9402
# Epoch 3/15
# 460/460 [==============================] - 57s 124ms/step - loss: 0.5116 - accuracy: 0.8439 - val_loss: 0.1170 - val_accuracy: 0.9714
# Epoch 4/15
# 460/460 [==============================] - 59s 128ms/step - loss: 0.3833 - accuracy: 0.8856 - val_loss: 0.0888 - val_accuracy: 0.9788
# Epoch 5/15
# 460/460 [==============================] - 59s 129ms/step - loss: 0.3000 - accuracy: 0.9101 - val_loss: 0.0770 - val_accuracy: 0.9809
# Epoch 6/15
# 460/460 [==============================] - 62s 136ms/step - loss: 0.2647 - accuracy: 0.9196 - val_loss: 0.0631 - val_accuracy: 0.9838
# Epoch 7/15
# 460/460 [==============================] - 58s 126ms/step - loss: 0.2387 - accuracy: 0.9305 - val_loss: 0.0747 - val_accuracy: 0.9820
# Epoch 8/15
# 460/460 [==============================] - 58s 126ms/step - loss: 0.1961 - accuracy: 0.9427 - val_loss: 0.0503 - val_accuracy: 0.9864
# Epoch 9/15
# 460/460 [==============================] - 57s 124ms/step - loss: 0.1847 - accuracy: 0.9451 - val_loss: 0.0385 - val_accuracy: 0.9911
# Epoch 10/15
# 460/460 [==============================] - 52s 114ms/step - loss: 0.1872 - accuracy: 0.9451 - val_loss: 0.0530 - val_accuracy: 0.9870
# Epoch 11/15
# 460/460 [==============================] - 55s 120ms/step - loss: 0.1713 - accuracy: 0.9507 - val_loss: 0.0290 - val_accuracy: 0.9933
# Epoch 12/15
# 460/460 [==============================] - 54s 116ms/step - loss: 0.1537 - accuracy: 0.9552 - val_loss: 0.0352 - val_accuracy: 0.9914
# Epoch 13/15
# 460/460 [==============================] - 55s 119ms/step - loss: 0.1476 - accuracy: 0.9590 - val_loss: 0.1801 - val_accuracy: 0.9571
# Epoch 14/15
# 460/460 [==============================] - 55s 120ms/step - loss: 0.1374 - accuracy: 0.9585 - val_loss: 0.0560 - val_accuracy: 0.9866
# Epoch 15/15
# 460/460 [==============================] - 54s 117ms/step - loss: 0.1267 - accuracy: 0.9634 - val_loss: 0.0290 - val_accuracy: 0.9929

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_test = pd.read_csv('Test.csv')

# %%
labels_test = y_test['ClassId'].values
img_test = y_test['Path'].values
test_dir = ''
data = []
for img in img_test:
    img_path = os.path.join(test_dir, img)
    image = cv2.imread(img_path, -1)
    image = cv2.resize(image, (64,64), interpolation = cv2.INTER_NEAREST)
    data.append(np.array(image))
X_test = np.array(data)

# %%
from sklearn.metrics import accuracy_score

pred = np.argmax(model.predict(X_test), axis=-1)

print("Test accuracy: ", accuracy_score(labels_test, pred) * 100 )
# Out:
# 395/395 [==============================] - 4s 11ms/step
# Test accuracy:  96.53998416468725
